# %%
#from google.colab import drive

# %%
#drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import hashlib
from scipy.stats import iqr
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# importing utility modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# importing machine learning models for prediction
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
#train=pd.read_csv("/content/drive/MyDrive/Datasets/train_data.csv")
train=pd.read_csv("pune.csv")
display(train)#display data
# Out:
#                date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0       11-12-2008 00:00        30        18             0     11.0        6
# 1       11-12-2008 01:00        30        18             0     11.0        6
# 2       11-12-2008 02:00        30        18             0     11.0        6
# 3       11-12-2008 03:00        30        18             0     11.0        6
# 4       11-12-2008 04:00        30        18             0     11.0        6
# ...                  ...       ...       ...           ...      ...      ...
# 116131  11-03-2022 19:00        35        23             0     11.8        7
# 116132  11-03-2022 20:00        35        23             0     11.8        7
# 116133  11-03-2022 21:00        35        23             0     11.8        7
# 116134  11-03-2022 22:00        35        23             0     11.8        7
# 116135  11-03-2022 23:00        35        23             0     11.8        7
#
#         moon_illumination  moonrise  moonset  sunrise  ... WindGustKmph  \
# 0                      93   4:33 PM  5:13 AM  6:57 AM  ...           10
# 1                      93   4:33 PM  5:13 AM  6:57 AM  ...            9
# 2                      93   4:33 PM  5:13 AM  6:57 AM  ...            8
# 3                      93   4:33 PM  5:13 AM  6:57 AM  ...            8
# 4                      93   4:33 PM  5:13 AM  6:57 AM  ...            7
# ...                   ...       ...      ...      ...  ...          ...
# 116131                 56  12:40 PM  1:33 AM  6:46 AM  ...           10
# 116132                 56  12:40 PM  1:33 AM  6:46 AM  ...           14
# 116133                 56  12:40 PM  1:33 AM  6:46 AM  ...           12
# 116134                 56  12:40 PM  1:33 AM  6:46 AM  ...           14
# 116135                 56  12:40 PM  1:33 AM  6:46 AM  ...           15
#
#         cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# 0               31        72       0.0      1013     18          10
# 1               30        72       0.0      1013     19          10
# 2               29        72       0.0      1013     18          10
# 3               29        72       0.0      1013     18          10
# 4               23        68       0.0      1014     20          10
# ...            ...       ...       ...       ...    ...         ...
# 116131           6        28       0.0      1009     30          10
# 116132           7        29       0.0      1010     29          10
# 116133           9        30       0.0      1012     27          10
# 116134           8        31       0.0      1011     26          10
# 116135           7        32       0.0      1011     25          10
#
#         winddirDegree  windspeedKmph  location
# 0                 114              5      pune
# 1                 125              4      pune
# 2                 136              4      pune
# 3                 147              4      pune
# 4                 136              4      pune
# ...               ...            ...       ...
# 116131            235              7      pune
# 116132            289              9      pune
# 116133            343             12      pune
# 116134            234             11      pune
# 116135            125             10      pune
#
# [116136 rows x 25 columns]

# %%
train.describe()
# Out:
#             maxtempC       mintempC  totalSnow_cm        sunHour  \
# count  116136.000000  116136.000000      116136.0  116136.000000
# mean       30.977475      20.987394           0.0      11.136041
# std         4.320621       2.701768           0.0       1.004464
# min        21.000000      11.000000           0.0       8.300000
# 25%        28.000000      19.000000           0.0      10.500000
# 50%        30.000000      21.000000           0.0      11.000000
# 75%        34.000000      23.000000           0.0      11.900000
# max        43.000000      28.000000           0.0      13.600000
#
#              uvIndex  moon_illumination      DewPointC     FeelsLikeC  \
# count  116136.000000      116136.000000  116136.000000  116136.000000
# mean        6.208927          46.087001      15.141722      26.170739
# std         0.921580          31.263676       6.093959       4.507061
# min         4.000000           0.000000     -12.000000      10.000000
# 25%         5.000000          18.000000      10.000000      25.000000
# 50%         6.000000          46.000000      16.000000      26.000000
# 75%         7.000000          73.000000      21.000000      29.000000
# max         8.000000         100.000000      25.000000      44.000000
#
#           HeatIndexC     WindChillC   WindGustKmph    cloudcover  \
# count  116136.000000  116136.000000  116136.000000  116136.00000
# mean       26.364383      25.304290      17.327823      31.43028
# std         4.355228       4.660732       8.147513      34.09457
# min        11.000000      10.000000       1.000000       0.00000
# 25%        25.000000      22.000000      11.000000       3.00000
# 50%        26.000000      24.000000      16.000000      12.00000
# 75%        29.000000      28.000000      22.000000      66.00000
# max        44.000000      43.000000      76.000000     100.00000
#
#             humidity       precipMM       pressure          tempC  \
# count  116136.000000  116136.000000  116136.000000  116136.000000
# mean       57.646001       0.231727    1009.731522      25.304720
# std        25.316012       0.802657       3.580792       4.659629
# min         4.000000       0.000000     997.000000      11.000000
# 25%        36.000000       0.000000    1007.000000      22.000000
# 50%        58.000000       0.000000    1010.000000      24.000000
# 75%        82.000000       0.100000    1012.000000      28.000000
# max       100.000000      25.700000    1021.000000      43.000000
#
#           visibility  winddirDegree  windspeedKmph
# count  116136.000000  116136.000000  116136.000000
# mean        9.409899     206.138863       9.397663
# std         1.593393      90.489701       4.775019
# min         0.000000       0.000000       0.000000
# 25%        10.000000     106.000000       6.000000
# 50%        10.000000     252.000000       9.000000
# 75%        10.000000     274.000000      12.000000
# max        10.000000     360.000000      40.000000

# %%
train.isnull().sum()
# Out:
# date_time            0
# maxtempC             0
# mintempC             0
# totalSnow_cm         0
# sunHour              0
# uvIndex              0
# moon_illumination    0
# moonrise             0
# moonset              0
# sunrise              0
# sunset               0
# DewPointC            0
# FeelsLikeC           0
# HeatIndexC           0
# WindChillC           0
# WindGustKmph         0
# cloudcover           0
# humidity             0
# precipMM             0
# pressure             0
# tempC                0
# visibility           0
# winddirDegree        0
# windspeedKmph        0
# location             0
# dtype: int64

# %%
data = train
data[['Date','Time']] = data['date_time'].str.split(' ',n=1,expand=True)

# %%
data
# Out:
#                date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0       11-12-2008 00:00        30        18             0     11.0        6
# 1       11-12-2008 01:00        30        18             0     11.0        6
# 2       11-12-2008 02:00        30        18             0     11.0        6
# 3       11-12-2008 03:00        30        18             0     11.0        6
# 4       11-12-2008 04:00        30        18             0     11.0        6
# ...                  ...       ...       ...           ...      ...      ...
# 116131  11-03-2022 19:00        35        23             0     11.8        7
# 116132  11-03-2022 20:00        35        23             0     11.8        7
# 116133  11-03-2022 21:00        35        23             0     11.8        7
# 116134  11-03-2022 22:00        35        23             0     11.8        7
# 116135  11-03-2022 23:00        35        23             0     11.8        7
#
#         moon_illumination  moonrise  moonset  sunrise  ... humidity  precipMM  \
# 0                      93   4:33 PM  5:13 AM  6:57 AM  ...       72       0.0
# 1                      93   4:33 PM  5:13 AM  6:57 AM  ...       72       0.0
# 2                      93   4:33 PM  5:13 AM  6:57 AM  ...       72       0.0
# 3                      93   4:33 PM  5:13 AM  6:57 AM  ...       72       0.0
# 4                      93   4:33 PM  5:13 AM  6:57 AM  ...       68       0.0
# ...                   ...       ...      ...      ...  ...      ...       ...
# 116131                 56  12:40 PM  1:33 AM  6:46 AM  ...       28       0.0
# 116132                 56  12:40 PM  1:33 AM  6:46 AM  ...       29       0.0
# 116133                 56  12:40 PM  1:33 AM  6:46 AM  ...       30       0.0
# 116134                 56  12:40 PM  1:33 AM  6:46 AM  ...       31       0.0
# 116135                 56  12:40 PM  1:33 AM  6:46 AM  ...       32       0.0
#
#         pressure  tempC  visibility  winddirDegree  windspeedKmph  location  \
# 0           1013     18          10            114              5      pune
# 1           1013     19          10            125              4      pune
# 2           1013     18          10            136              4      pune
# 3           1013     18          10            147              4      pune
# 4           1014     20          10            136              4      pune
# ...          ...    ...         ...            ...            ...       ...
# 116131      1009     30          10            235              7      pune
# 116132      1010     29          10            289              9      pune
# 116133      1012     27          10            343             12      pune
# 116134      1011     26          10            234             11      pune
# 116135      1011     25          10            125             10      pune
#
#               Date   Time
# 0       11-12-2008  00:00
# 1       11-12-2008  01:00
# 2       11-12-2008  02:00
# 3       11-12-2008  03:00
# 4       11-12-2008  04:00
# ...            ...    ...
# 116131  11-03-2022  19:00
# 116132  11-03-2022  20:00
# 116133  11-03-2022  21:00
# 116134  11-03-2022  22:00
# 116135  11-03-2022  23:00
#
# [116136 rows x 27 columns]

# %%
data[['Date','Month']] = data['Date'].str.split('-',n=1,expand=True)
data[['Month','Year']] = data['Month'].str.split('-',n=1,expand=True)

# %%
#data.drop(['location','date_time'],axis=1,inplace=True)

# %%
data
# Out:
#                date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0       11-12-2008 00:00        30        18             0     11.0        6
# 1       11-12-2008 01:00        30        18             0     11.0        6
# 2       11-12-2008 02:00        30        18             0     11.0        6
# 3       11-12-2008 03:00        30        18             0     11.0        6
# 4       11-12-2008 04:00        30        18             0     11.0        6
# ...                  ...       ...       ...           ...      ...      ...
# 116131  11-03-2022 19:00        35        23             0     11.8        7
# 116132  11-03-2022 20:00        35        23             0     11.8        7
# 116133  11-03-2022 21:00        35        23             0     11.8        7
# 116134  11-03-2022 22:00        35        23             0     11.8        7
# 116135  11-03-2022 23:00        35        23             0     11.8        7
#
#         moon_illumination  moonrise  moonset  sunrise  ... pressure  tempC  \
# 0                      93   4:33 PM  5:13 AM  6:57 AM  ...     1013     18
# 1                      93   4:33 PM  5:13 AM  6:57 AM  ...     1013     19
# 2                      93   4:33 PM  5:13 AM  6:57 AM  ...     1013     18
# 3                      93   4:33 PM  5:13 AM  6:57 AM  ...     1013     18
# 4                      93   4:33 PM  5:13 AM  6:57 AM  ...     1014     20
# ...                   ...       ...      ...      ...  ...      ...    ...
# 116131                 56  12:40 PM  1:33 AM  6:46 AM  ...     1009     30
# 116132                 56  12:40 PM  1:33 AM  6:46 AM  ...     1010     29
# 116133                 56  12:40 PM  1:33 AM  6:46 AM  ...     1012     27
# 116134                 56  12:40 PM  1:33 AM  6:46 AM  ...     1011     26
# 116135                 56  12:40 PM  1:33 AM  6:46 AM  ...     1011     25
#
#         visibility  winddirDegree  windspeedKmph  location  Date   Time  \
# 0               10            114              5      pune    11  00:00
# 1               10            125              4      pune    11  01:00
# 2               10            136              4      pune    11  02:00
# 3               10            147              4      pune    11  03:00
# 4               10            136              4      pune    11  04:00
# ...            ...            ...            ...       ...   ...    ...
# 116131          10            235              7      pune    11  19:00
# 116132          10            289              9      pune    11  20:00
# 116133          10            343             12      pune    11  21:00
# 116134          10            234             11      pune    11  22:00
# 116135          10            125             10      pune    11  23:00
#
#         Month  Year
# 0          12  2008
# 1          12  2008
# 2          12  2008
# 3          12  2008
# 4          12  2008
# ...       ...   ...
# 116131     03  2022
# 116132     03  2022
# 116133     03  2022
# 116134     03  2022
# 116135     03  2022
#
# [116136 rows x 29 columns]

# %%
data.drop(['location','date_time'],axis=1,inplace=True)

# %%
convert_dict = {'Date': int,
                'Month': int,
                'Year' : int
                }
 
data = data.astype(convert_dict)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116136 entries, 0 to 116135
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   maxtempC           116136 non-null  int64
#  1   mintempC           116136 non-null  int64
#  2   totalSnow_cm       116136 non-null  int64
#  3   sunHour            116136 non-null  float64
#  4   uvIndex            116136 non-null  int64
#  5   moon_illumination  116136 non-null  int64
#  6   moonrise           116136 non-null  object
#  7   moonset            116136 non-null  object
#  8   sunrise            116136 non-null  object
#  9   sunset             116136 non-null  object
#  10  DewPointC          116136 non-null  int64
#  11  FeelsLikeC         116136 non-null  int64
#  12  HeatIndexC         116136 non-null  int64
#  13  WindChillC         116136 non-null  int64
#  14  WindGustKmph       116136 non-null  int64
#  15  cloudcover         116136 non-null  int64
#  16  humidity           116136 non-null  int64
#  17  precipMM           116136 non-null  float64
#  18  pressure           116136 non-null  int64
#  19  tempC              116136 non-null  int64
#  20  visibility         116136 non-null  int64
#  21  winddirDegree      116136 non-null  int64
#  22  windspeedKmph      116136 non-null  int64
#  23  Date               116136 non-null  int32
#  24  Time               116136 non-null  object
#  25  Month              116136 non-null  int32
#  26  Year               116136 non-null  int32
# dtypes: float64(2), int32(3), int64(17), object(5)
# memory usage: 22.6+ MB

# %%
# train['year'] = train['date_time'].dt.year
# train['month'] = train['date_time'].dt.month
# train['day_of_year'] = train['date_time'].dt.dayofyear
# train['time'] = train['date_time'].dt.time

# %%
data.drop(['moonrise','moonset','sunrise','sunset'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116136 entries, 0 to 116135
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   maxtempC           116136 non-null  int64
#  1   mintempC           116136 non-null  int64
#  2   totalSnow_cm       116136 non-null  int64
#  3   sunHour            116136 non-null  float64
#  4   uvIndex            116136 non-null  int64
#  5   moon_illumination  116136 non-null  int64
#  6   DewPointC          116136 non-null  int64
#  7   FeelsLikeC         116136 non-null  int64
#  8   HeatIndexC         116136 non-null  int64
#  9   WindChillC         116136 non-null  int64
#  10  WindGustKmph       116136 non-null  int64
#  11  cloudcover         116136 non-null  int64
#  12  humidity           116136 non-null  int64
#  13  precipMM           116136 non-null  float64
#  14  pressure           116136 non-null  int64
#  15  tempC              116136 non-null  int64
#  16  visibility         116136 non-null  int64
#  17  winddirDegree      116136 non-null  int64
#  18  windspeedKmph      116136 non-null  int64
#  19  Date               116136 non-null  int32
#  20  Time               116136 non-null  object
#  21  Month              116136 non-null  int32
#  22  Year               116136 non-null  int32
# dtypes: float64(2), int32(3), int64(17), object(1)
# memory usage: 19.1+ MB

# %%
data['Time'].unique()
# Out:
# array(['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00',
#        '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00',
#        '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00',
#        '21:00', '22:00', '23:00'], dtype=object)

# %%
Timeformat = {'00:00': 24,'01:00': 1,'02:00': 2,'03:00': 3,'04:00': 4,'05:00': 5,'06:00': 6,'07:00': 7,'08:00': 8,'09:00': 9,
              '10:00': 10,'11:00': 11,'12:00': 12,'13:00': 13,'14:00': 14,'15:00': 15,'16:00': 16,'17:00': 17,'18:00': 18,
              '19:00': 19,'20:00': 20,'21:00': 21,'22:00': 22,'23:00': 23,}
data['Time'] = data['Time'].map(Timeformat)

# %%
convert_dict = {'Date': int,
                'Month': int,
                'Year' : int,
                'Time' : int
                }
 
data = data.astype(convert_dict)

# %%
data
# Out:
#         maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  moon_illumination  \
# 0             30        18             0     11.0        6                 93
# 1             30        18             0     11.0        6                 93
# 2             30        18             0     11.0        6                 93
# 3             30        18             0     11.0        6                 93
# 4             30        18             0     11.0        6                 93
# ...          ...       ...           ...      ...      ...                ...
# 116131        35        23             0     11.8        7                 56
# 116132        35        23             0     11.8        7                 56
# 116133        35        23             0     11.8        7                 56
# 116134        35        23             0     11.8        7                 56
# 116135        35        23             0     11.8        7                 56
#
#         DewPointC  FeelsLikeC  HeatIndexC  WindChillC  ...  precipMM  \
# 0              13          18          18          18  ...       0.0
# 1              14          19          19          19  ...       0.0
# 2              13          18          18          18  ...       0.0
# 3              13          18          18          18  ...       0.0
# 4              13          20          20          20  ...       0.0
# ...           ...         ...         ...         ...  ...       ...
# 116131          9          28          28          30  ...       0.0
# 116132          9          28          28          29  ...       0.0
# 116133         11          26          26          27  ...       0.0
# 116134         11          26          26          26  ...       0.0
# 116135         11          25          25          25  ...       0.0
#
#         pressure  tempC  visibility  winddirDegree  windspeedKmph  Date  Time  \
# 0           1013     18          10            114              5    11    24
# 1           1013     19          10            125              4    11     1
# 2           1013     18          10            136              4    11     2
# 3           1013     18          10            147              4    11     3
# 4           1014     20          10            136              4    11     4
# ...          ...    ...         ...            ...            ...   ...   ...
# 116131      1009     30          10            235              7    11    19
# 116132      1010     29          10            289              9    11    20
# 116133      1012     27          10            343             12    11    21
# 116134      1011     26          10            234             11    11    22
# 116135      1011     25          10            125             10    11    23
#
#         Month  Year
# 0          12  2008
# 1          12  2008
# 2          12  2008
# 3          12  2008
# 4          12  2008
# ...       ...   ...
# 116131      3  2022
# 116132      3  2022
# 116133      3  2022
# 116134      3  2022
# 116135      3  2022
#
# [116136 rows x 23 columns]

# %%
y = data['maxtempC']
x = data[['Date','Month','Year','Time']]

# %%
x
# Out:
#         Date  Month  Year  Time
# 0         11     12  2008    24
# 1         11     12  2008     1
# 2         11     12  2008     2
# 3         11     12  2008     3
# 4         11     12  2008     4
# ...      ...    ...   ...   ...
# 116131    11      3  2022    19
# 116132    11      3  2022    20
# 116133    11      3  2022    21
# 116134    11      3  2022    22
# 116135    11      3  2022    23
#
# [116136 rows x 4 columns]

# %%
y
# Out:
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30
#           ..
# 116131    35
# 116132    35
# 116133    35
# 116134    35
# 116135    35
# Name: maxtempC, Length: 116136, dtype: int64

# %%
from sklearn.model_selection import train_test_split
#splitting
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn import svm
model = svm.SVC()

model.fit(x_train,y_train)

# %%
from sklearn.metrics import classification_report, accuracy_score
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
